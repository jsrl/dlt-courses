# %% [markdown]
# # Transforming and filtering the data
#
# In this lesson, we will take a look at various ways of doing data transformations and filtering of the data during and after the ingestion.
#
# dlt provides several ways of doing it during the ingestion:
# 1. With custom query (applicable for `sql_database` source).
# 2. With dlt special functions (`add_map` and `add_filter`).
# 3. Via `@dlt.transformers`.
# 4. With `pipeline.dataset()`.
#
# Let's review and compare those methods.

# %% [markdown]
# ##  What you’ll learn:
#
# - How to limit rows at the source with SQL queries.
# - How to apply custom Python logic per record.
# - How to write transformations using functional and declarative APIs.
# - How to access and query your loaded data using `.dataset()`.

# %% [markdown]
# ## Setup and initial Load

# %% [markdown]
# We will be using the `sql_database` source as an example and will connect to the public [MySQL RFam](https://www.google.com/url?q=https%3A%2F%2Fwww.google.com%2Furl%3Fq%3Dhttps%253A%252F%252Fdocs.rfam.org%252Fen%252Flatest%252Fdatabase.html) database. The RFam database contains publicly accessible scientific data on RNA structures.
#
# Let's perform an initial load:

# %%
# %%capture
# !pip install "dlt[sql_database, duckdb]"
# !pip install pymysql

# %%
import dlt

from dlt.sources.sql_database import sql_database

source = sql_database(
    "mysql+pymysql://rfamro@mysql-rfam-public.ebi.ac.uk:4497/Rfam",
    table_names=["family","genome"]
)

pipeline = dlt.pipeline(
    pipeline_name="sql_database_pipeline",
    destination="duckdb",
    dataset_name="sql_data",
)
load_info = pipeline.run(source)
print(load_info)
# Out:
# Pipeline sql_database_pipeline load step completed in 10.13 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline.duckdb location to store data
# Load package 1746871155.2125173 is LOADED and contains no failed jobs

# %%
with pipeline.sql_client() as client:
  with client.execute_query("SELECT * FROM genome") as table:
      genome = table.df()
genome
# Out:
#               upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0      RG000000001             None               NaN    None          NaN
# 1      RG000000002             None               NaN    None          NaN
# 2      RG000000003             None               NaN    None          NaN
# 3      RG000000004             None               NaN    None          NaN
# 4      RG000000005             None               NaN    None          NaN
# ...            ...              ...               ...     ...          ...
# 96502  UP001295980  GCA_963583275.1               1.0    None          NaN
# 96503  UP001296009  GCA_963583145.1               1.0    None          NaN
# 96504  UP001296230  GCA_963583065.1               1.0    None          NaN
# 96505  UP001296237  GCA_963583445.1               1.0    None          NaN
# 96506            x             None               NaN    None          NaN
#
#       assembly_name assembly_level study_ref  \
# 0              None           None      None
# 1              None           None      None
# 2              None           None      None
# 3              None           None      None
# 4              None           None      None
# ...             ...            ...       ...
# 96502          None           None      None
# 96503          None           None      None
# 96504          None           None      None
# 96505          None           None      None
# 96506     ASM2700v1           None      None
#
#                                              description  total_length  ...  \
# 0                            Potato spindle tuber viroid          4591  ...
# 1                                 Columnea latent viroid           370  ...
# 2                           Tomato apical stunt viroid-S           360  ...
# 3                             Tomato apical stunt viroid           360  ...
# 4                                 Cucumber yellows virus          7899  ...
# ...                                                  ...           ...  ...
# 96502                                               None         44107  ...
# 96503                                               None         43831  ...
# 96504                                               None         40906  ...
# 96505                                               None         42982  ...
# 96506  Pichia pastoris has been reassigned to the gen...       9216378  ...
#
#        common_name    kingdom  num_rfam_regions num_families is_reference  \
# 0             None    viroids                 0            0            1
# 1             None    viroids                 0            0            1
# 2             None    viroids                 0            0            1
# 3             None    viroids                 0            0            1
# 4             None    viruses                 0            0            1
# ...            ...        ...               ...          ...          ...
# 96502         None    viruses                 0            0            0
# 96503         None    viruses                 0            0            0
# 96504         None    viruses                 0            0            0
# 96505         None    viruses                 0            0            0
# 96506         None  eukaryota                 0            0            1
#
#       is_representative                   created                   updated  \
# 0                     0 2017-06-06 15:11:02+00:00 2020-04-23 11:46:08+00:00
# 1                     0 2017-06-06 15:11:07+00:00 2020-04-23 11:46:08+00:00
# 2                     0 2017-06-06 15:11:12+00:00 2020-04-23 11:47:10+00:00
# 3                     0 2017-06-06 15:11:17+00:00 2020-04-23 11:46:08+00:00
# 4                     0 2017-06-06 15:11:21+00:00 2020-04-23 11:46:28+00:00
# ...                 ...                       ...                       ...
# 96502                 0 2024-06-27 09:26:33+00:00 2024-09-02 20:32:58+00:00
# 96503                 0 2024-06-28 19:29:45+00:00 2024-09-02 20:32:58+00:00
# 96504                 0 2024-06-27 09:19:44+00:00 2024-09-02 20:32:58+00:00
# 96505                 0 2024-06-28 19:34:50+00:00 2024-09-02 20:32:58+00:00
# 96506                 1 2017-05-15 11:09:53+00:00 2020-04-23 11:53:16+00:00
#
#              _dlt_load_id         _dlt_id
# 0      1746870338.0995858  H9gGlZfDnwGJNw
# 1      1746870338.0995858  axdQXOJYhvDWnw
# 2      1746870338.0995858  wxN/7zvjfM+xzg
# 3      1746870338.0995858  aIoLRtZOn8Thag
# 4      1746870338.0995858  XmeoWhZ7heNLlg
# ...                   ...             ...
# 96502  1746871155.2125173  FuHnU16vOUGpHQ
# 96503  1746871155.2125173  Opyr+QQOgMayMA
# 96504  1746871155.2125173  hh+uCqGoxcm8Kg
# 96505  1746871155.2125173  FuNFFCUQSKHyBA
# 96506  1746871155.2125173  VMdN+kJVSaIFeQ
#
# [96507 rows x 24 columns]

# %% [markdown]
# You can check your data count using `sql_client`:

# %%
with pipeline.sql_client() as client:
  with client.execute_query("SELECT COUNT(*) AS total_rows FROM genome") as table:
      print(table.df())
# Out:
#    total_rows
# 0       96507

# %% [markdown]
# ## **1. Filtering the data during the ingestion with `query_adapter_callback`**

# %% [markdown]
# Imagine a use-case where we're only interested in getting the genome data for bacterias. In this case, ingesting the whole `genome` table would be an unnecessary use of time and compute resources.

# %%
with pipeline.sql_client() as client:
  with client.execute_query("SELECT COUNT(*) AS total_rows FROM genome WHERE kingdom='bacteria'") as table:
      print(table.df())
# Out:
#    total_rows
# 0       41763

# %% [markdown]
# When ingesting data using the `sql_database` source, dlt runs a `SELECT` statement in the back, and using the `query_adapter_callback` parameter makes it possible to pass a `WHERE` clause inside the underlying `SELECT` statement.
#
# In this example, only the table `genome` is filtered on the column `kingdom`

# %%
def query_adapter_callback(query, table):
    if table.name == "genome":
        # Only select rows where the column kingdom has value "bacteria"
        return query.where(table.c.kingdom=="bacteria")
    # Use the original query for other tables
    return query

# %% [markdown]
# Attach it:

# %%
import dlt
from dlt.sources.sql_database import sql_database


source = sql_database(
    "mysql+pymysql://rfamro@mysql-rfam-public.ebi.ac.uk:4497/Rfam",
    table_names=["genome"],
    query_adapter_callback=query_adapter_callback
)


pipeline = dlt.pipeline(
    pipeline_name="sql_database_pipeline_filtered",
    destination="duckdb",
    dataset_name="sql_data"
)

load_info = pipeline.run(source, write_disposition="replace")

print(pipeline.last_trace)
# Out:
# Run started at 2025-05-10 09:59:46.747678+00:00 and COMPLETED in 12.64 seconds with 4 steps.
# Step extract COMPLETED in 6.23 seconds.
#
# Load package 1746871186.894474 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 1.83 seconds.
# Normalized data for the following tables:
# - genome: 13921 row(s)
#
# Load package 1746871186.894474 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step load COMPLETED in 4.47 seconds.
# Pipeline sql_database_pipeline_filtered load step completed in 4.33 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline_filtered.duckdb location to store data
# Load package 1746871186.894474 is LOADED and contains no failed jobs
#
# Step run COMPLETED in 12.64 seconds.
# Pipeline sql_database_pipeline_filtered load step completed in 4.33 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline_filtered.duckdb location to store data
# Load package 1746871186.894474 is LOADED and contains no failed jobs

# %% [markdown]
# In the snippet above we created an SQL VIEW in your source database and extracted data from it. In that case, dlt will infer all column types and read data in shape you define in a view without any further customization.
#
# If creating a view is not feasible, you can fully rewrite the automatically generated query with an extended version of `query_adapter_callback`:

# %%
import dlt
import sqlalchemy as sa

from dlt.sources.sql_database import sql_database


def query_adapter_callback(query, table):
  if table.name == "genome":
    return sa.text(f"SELECT * FROM {table.fullname} WHERE kingdom='bacteria'")
  return query


source = sql_database(
    "mysql+pymysql://rfamro@mysql-rfam-public.ebi.ac.uk:4497/Rfam",
    table_names=["genome", "clan"],
    query_adapter_callback=query_adapter_callback
)


pipeline = dlt.pipeline(
    pipeline_name="sql_database_pipeline_filtered",
    destination="duckdb",
    dataset_name="sql_data"

)

load_info = pipeline.run(source, write_disposition="replace")

print(load_info)
# Out:
# Pipeline sql_database_pipeline_filtered load step completed in 3.55 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline_filtered.duckdb location to store data
# Load package 1746871201.6816118 is LOADED and contains no failed jobs

# %%
with pipeline.sql_client() as client:

    with client.execute_query("SELECT COUNT(*) AS total_rows, MAX(_dlt_load_id) as latest_load_id FROM clan") as table:
        print("Table clan:")
        print(table.df())
        print("\n")

    with client.execute_query("SELECT COUNT(*) AS total_rows, MAX(_dlt_load_id) as latest_load_id FROM genome") as table:
        print("Table genome:")
        print(table.df())
# Out:
# Table clan:
#    total_rows      latest_load_id
# 0         147  1746871201.6816118
#
#
# Table genome:
#    total_rows      latest_load_id
# 0       13921  1746871201.6816118

# %% [markdown]
# ## **2. Transforming the data after extract and before load**

# %% [markdown]
# Since dlt is a Python library, it gives you a lot of control over the extracted data.
#
# You can attach any number of transformations that are evaluated on an item-per-item basis to your resource. The available transformation types:
#
# * `map` - transform the data item (resource.add_map).
# * `filter` - filter the data item (resource.add_filter).
# * `yield map` - a map that returns an iterator (so a single row may generate many rows - resource.add_yield_map).
# * `limit` - limits the number of records processed by a resource. Useful for testing or reducing data volume during development.
#
# For example, if we wanted to anonymize sensitive data before it is loaded into the destination, then we can write a python function for it and apply it to source or resource using the `.add_map()` method.
#
# [dlt documentation.](https://dlthub.com/docs/general-usage/resource#filter-transform-and-pivot-data)

# %% [markdown]
# ### Using `add_map`

# %% [markdown]
# In the table `clan`, we notice that there is a column `author` that we would like to anonymize.

# %%
with pipeline.sql_client() as client:

    with client.execute_query("SELECT DISTINCT author FROM clan LIMIT 5") as table:
        print("Table clan:")
        print(table.df())
# Out:
# Table clan:
#                             author
# 0                       Gardner PP
# 1  Gardner PP; 0000-0002-7808-1213
# 2                           Daub J
# 3                          Brown C
# 4                         Burge SW

# %% [markdown]
# We write a function in python that anonymizes a string

# %%
import hashlib

def pseudonymize_name(row):
    '''
    Pseudonymization is a deterministic type of PII-obscuring.
    Its role is to allow identifying users by their hash,
    without revealing the underlying info.
    '''
    # add a constant salt to generate
    salt = 'WI@N57%zZrmk#88c'
    salted_string = row['author'] + salt
    sh = hashlib.sha256()
    sh.update(salted_string.encode())
    hashed_string = sh.digest().hex()
    row['author'] = hashed_string
    return row

# %%
import dlt
import hashlib
from dlt.sources.sql_database import sql_database


pipeline = dlt.pipeline(
    pipeline_name="sql_database_pipeline_anonymized",
    destination="duckdb",
    dataset_name="sql_data"
)


source = sql_database("mysql+pymysql://rfamro@mysql-rfam-public.ebi.ac.uk:4497/Rfam", table_names=["clan"])

source.clan.add_map(pseudonymize_name) # Apply the anonymization function to the extracted data

info = pipeline.run(source)
print(info)
# Out:
# Pipeline sql_database_pipeline_anonymized load step completed in 0.11 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline_anonymized.duckdb location to store data
# Load package 1746871217.3990965 is LOADED and contains no failed jobs

# %% [markdown]
# After the pipeline has run, we can observe that the author column has been anonymized.

# %%
with pipeline.sql_client() as client:

    with client.execute_query("SELECT DISTINCT author FROM clan LIMIT 5") as table:
        print("Table clan:")
        clan = table.df()

clan
# Out:
# Table clan:
#                                               author
# 0  eb00a968f270b436a506949ba46fd70a66591c5acf2b57...
# 1  c6723bd5737f14a8d4b2e447a063ce547be1f88c7b6450...
# 2  9766eaa9533fcb3684649b2e4a5db9573f1bf10f103ed4...
# 3  bee07cbb64f4e771a4bd9327afd9244e9a5dbc3aa957d9...
# 4  9d281938612b0b9646c75049e817208c236431dee86583...

# %% [markdown]
# **Note:** If you're using the `pyarrow` or `connectorx` backend, the data is not processed item-by-item. Instead they're processed in batches, therefore your function should be adjusted. For example, for PyArrow chunks the function could be changed as follows:

# %%
import hashlib
import pyarrow as pa
import pyarrow.compute as pc


def pseudonymize_name_pyarrow(table: pa.Table) -> pa.Table:
    """
    Pseudonymizes the 'author' column in a PyArrow Table.
    """
    salt = 'WI@N57%zZrmk#88c'

    # Convert PyArrow Table to Pandas DataFrame for hashing
    df = table.to_pandas()

    # Apply SHA-256 hashing
    df['author'] = df['author'].astype(str).apply(lambda x: hashlib.sha256((x + salt).encode()).hexdigest())

    # Convert back to PyArrow Table
    new_table = pa.Table.from_pandas(df)

    return new_table

pipeline = dlt.pipeline(
    pipeline_name="sql_database_pipeline_anonymized1",
    destination="duckdb",
    dataset_name="sql_data"
)


source = sql_database(
    "mysql+pymysql://rfamro@mysql-rfam-public.ebi.ac.uk:4497/Rfam",
    table_names=["clan"],
    backend="pyarrow",
    )

source.clan.add_map(pseudonymize_name_pyarrow) # Apply the anonymization function to the extracted data

info = pipeline.run(source)
print(info)
# Out:
# 2025-05-10 10:00:23,627|[WARNING]|3782|136150084866048|dlt|extractors.py|_compute_tables:475|In resource: clan, when merging arrow schema with dlt schema, several column hints were different. dlt schema hints were kept and arrow schema and data were unmodified. It is up to destination to coerce the differences when loading. Change log level to INFO for more details.
# Pipeline sql_database_pipeline_anonymized1 load step completed in 0.09 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline_anonymized1.duckdb location to store data
# Load package 1746871221.826223 is LOADED and contains no failed jobs

# %%
with pipeline.sql_client() as client:

    with client.execute_query("SELECT DISTINCT author FROM clan LIMIT 5") as table:
        print("Table clan:")
        print(table.df())
# Out:
# Table clan:
#                                               author
# 0  eb00a968f270b436a506949ba46fd70a66591c5acf2b57...
# 1  c6723bd5737f14a8d4b2e447a063ce547be1f88c7b6450...
# 2  9766eaa9533fcb3684649b2e4a5db9573f1bf10f103ed4...
# 3  bee07cbb64f4e771a4bd9327afd9244e9a5dbc3aa957d9...
# 4  9d281938612b0b9646c75049e817208c236431dee86583...

# %% [markdown]
# ### `add_map` vs `add_yield_map`
#
# The difference between `add_map` and `add_yield_map` matters when a transformation returns multiple records from a single input.
#
# - **`add_map`**: The function should return a list. `dlt` flattens this list into separate records.
# - **`add_yield_map`**: The function should yield one record at a time.
#
# `add_yield_map` lets you yield records one at a time, giving better control over processing. This is helpful when your logic requires conditional output, filtering, or more granular handling.

# %% [markdown]
# ### Using `add_filter`
# `add_filter` function can be used similarly. The difference is that `add_filter` expects a function that returns a boolean value for each item. For example, to implement the same filtering we did with a query callback, we can use:

# %%
import time
import dlt
from dlt.sources.sql_database import sql_database


source = sql_database(
    "mysql+pymysql://rfamro@mysql-rfam-public.ebi.ac.uk:4497/Rfam",
    table_names=["genome"]
)


pipeline = dlt.pipeline(
    pipeline_name="sql_database_pipeline_filtered",
    destination="duckdb",
    dataset_name="sql_data"
)
source.genome.add_filter(lambda item: item["kingdom"] == "bacteria")

load_info = pipeline.run(source, write_disposition="replace")

print(pipeline.last_trace)
# Out:
# Run started at 2025-05-10 10:00:25.995102+00:00 and COMPLETED in 13.43 seconds with 4 steps.
# Step extract COMPLETED in 7.70 seconds.
#
# Load package 1746871226.0582514 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 2.17 seconds.
# Normalized data for the following tables:
# - genome: 13921 row(s)
#
# Load package 1746871226.0582514 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step load COMPLETED in 3.52 seconds.
# Pipeline sql_database_pipeline_filtered load step completed in 3.38 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline_filtered.duckdb location to store data
# Load package 1746871226.0582514 is LOADED and contains no failed jobs
#
# Step run COMPLETED in 13.43 seconds.
# Pipeline sql_database_pipeline_filtered load step completed in 3.38 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline_filtered.duckdb location to store data
# Load package 1746871226.0582514 is LOADED and contains no failed jobs

# %%
with pipeline.sql_client() as client:
    with client.execute_query("SELECT COUNT(*) AS total_rows, MAX(_dlt_load_id) as latest_load_id FROM genome") as table:
        print("Table genome:")
        genome_count = table.df()
genome_count
# Out:
# Table genome:
#    total_rows      latest_load_id
# 0       13921  1746871226.0582514

# %% [markdown]
# ### Question 1:
#
# What is a `total_rows` in the example above?
#
# **-->13921**

# %% [markdown]
# ### Using `add_limit`
#
# If your resource loads thousands of pages of data from a REST API or millions of rows from a database table, you may want to sample just a fragment of it in order to quickly see the dataset with example data and test your transformations, etc.
#
# To do this, you limit how many items will be yielded by a resource (or source) by calling the `add_limit` method. This method will close the generator that produces the data after the limit is reached.

# %%
import time
import dlt
from dlt.sources.sql_database import sql_database


source = sql_database(
    "mysql+pymysql://rfamro@mysql-rfam-public.ebi.ac.uk:4497/Rfam",
    table_names=["genome"],
    chunk_size=10,
)


pipeline = dlt.pipeline(
    pipeline_name="sql_database_pipeline_filtered",
    destination="duckdb",
    dataset_name="sql_data"
)
source.genome.add_limit(1)

load_info = pipeline.run(source, write_disposition="replace")

print(pipeline.last_trace)
# Out:
# /usr/local/lib/python3.11/dist-packages/pymysql/connections.py:849: UserWarning: Previous unbuffered result was left incomplete
#   warnings.warn("Previous unbuffered result was left incomplete")
# Run started at 2025-05-10 10:00:41.543970+00:00 and COMPLETED in 5.98 seconds with 4 steps.
# Step extract COMPLETED in 5.77 seconds.
#
# Load package 1746871241.6095686 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 0.03 seconds.
# Normalized data for the following tables:
# - genome: 10 row(s)
#
# Load package 1746871241.6095686 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step load COMPLETED in 0.13 seconds.
# Pipeline sql_database_pipeline_filtered load step completed in 0.12 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline_filtered.duckdb location to store data
# Load package 1746871241.6095686 is LOADED and contains no failed jobs
#
# Step run COMPLETED in 5.98 seconds.
# Pipeline sql_database_pipeline_filtered load step completed in 0.12 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data
# The duckdb destination used duckdb:////content/sql_database_pipeline_filtered.duckdb location to store data
# Load package 1746871241.6095686 is LOADED and contains no failed jobs

# %%
with pipeline.sql_client() as client:
  with client.execute_query("SELECT * FROM genome") as table:
      genome_limited = table.df()
genome_limited
# Out:
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  RG000000001             None               NaN    None          NaN
# 1  RG000000002             None               NaN    None          NaN
# 2  RG000000003             None               NaN    None          NaN
# 3  RG000000004             None               NaN    None          NaN
# 4  RG000000005             None               NaN    None          NaN
# 5  RG000000006             None               NaN    None          NaN
# 6  RG000000007  GCA_000413255.1               1.0    None          NaN
# 7  RG000000009  GCF_000836845.1               1.0    None          NaN
# 8  RG000000010  GCF_000840125.1               1.0    None          NaN
# 9  RG000000011  GCF_000847605.1               1.0    None          NaN
#
#   assembly_name assembly_level study_ref  \
# 0          None           None      None
# 1          None           None      None
# 2          None           None      None
# 3          None           None      None
# 4          None           None      None
# 5          None           None      None
# 6          None           None      None
# 7          None           None      None
# 8          None           None      None
# 9          None           None      None
#
#                                         description  total_length  ...  \
# 0                       Potato spindle tuber viroid          4591  ...
# 1                            Columnea latent viroid           370  ...
# 2                      Tomato apical stunt viroid-S           360  ...
# 3                        Tomato apical stunt viroid           360  ...
# 4                            Cucumber yellows virus          7899  ...
# 5  Caprine arthritis encephalitis virus Roccaverano          8418  ...
# 6                             Physarum polycephalum     189961418  ...
# 7           Arabis mosaic virus small satellite RNA           300  ...
# 8              Tobacco ringspot virus satellite RNA           359  ...
# 9                    Equine infectious anemia virus          8359  ...
#
#    common_name    kingdom  num_rfam_regions num_families is_reference  \
# 0         None    viroids                 0            0            1
# 1         None    viroids                 0            0            1
# 2         None    viroids                 0            0            1
# 3         None    viroids                 0            0            1
# 4         None    viruses                 0            0            1
# 5         None    viruses                 0            0            1
# 6         None  eukaryota                 0            0            1
# 7         None    viruses                 0            0            1
# 8         None    viruses                 0            0            1
# 9         None    viruses                 0            0            1
#
#   is_representative                   created                   updated  \
# 0                 0 2017-06-06 15:11:02+00:00 2020-04-23 11:46:08+00:00
# 1                 0 2017-06-06 15:11:07+00:00 2020-04-23 11:46:08+00:00
# 2                 0 2017-06-06 15:11:12+00:00 2020-04-23 11:47:10+00:00
# 3                 0 2017-06-06 15:11:17+00:00 2020-04-23 11:46:08+00:00
# 4                 0 2017-06-06 15:11:21+00:00 2020-04-23 11:46:28+00:00
# 5                 0 2017-06-06 15:11:24+00:00 2020-04-23 11:52:32+00:00
# 6                 0 2017-06-06 15:11:28+00:00 2020-04-23 11:44:55+00:00
# 7                 0 2017-06-06 15:11:43+00:00 2020-04-23 11:49:54+00:00
# 8                 0 2017-06-06 15:11:48+00:00 2020-04-23 11:46:26+00:00
# 9                 0 2017-06-06 15:11:52+00:00 2020-04-23 11:46:01+00:00
#
#          _dlt_load_id         _dlt_id
# 0  1746871241.6095686  uxLAfj89r1Zu5w
# 1  1746871241.6095686  7QHOolkOytXCag
# 2  1746871241.6095686  ddRsKiZ20zvoQg
# 3  1746871241.6095686  q5EijxY86JdE6w
# 4  1746871241.6095686  ZptJqod/eBrSzg
# 5  1746871241.6095686  AqOjM1V52qV+kg
# 6  1746871241.6095686  iFrv3OcKk7OJXQ
# 7  1746871241.6095686  j4JnvCc9zK3Wcg
# 8  1746871241.6095686  W7Iqyo6+18EVBA
# 9  1746871241.6095686  7KCXkxVqK1Bo/w
#
# [10 rows x 24 columns]

# %% [markdown]
# ## **3. Transforming data with `@dlt.transformer`**
#
# The main purpose of transformers is to create children tables with additional data requests, but they can also be used for data transformations especially if you want to keep the original data as well.

# %%
import time

import dlt
import hashlib
from dlt.sources.sql_database import sql_database


@dlt.transformer()
def batch_stats(items):
    '''
    Pseudonymization is a deterministic type of PII-obscuring.
    Its role is to allow identifying users by their hash,
    without revealing the underlying info.
    '''
    # add a constant salt to generate
    yield {"batch_length": len(items), "max_length": max([item["total_length"] for item in items])}


source = sql_database(
    "mysql+pymysql://rfamro@mysql-rfam-public.ebi.ac.uk:4497/Rfam",
    chunk_size=10000
    ).genome


pipeline = dlt.pipeline(
    pipeline_name="sql_database_pipeline_with_transformers1",
    destination="duckdb",
    dataset_name="sql_data",
    dev_mode=True
)

info = pipeline.run([source, source | batch_stats])
print(pipeline.last_trace)
# Out:
# Run started at 2025-05-10 10:00:57.523005+00:00 and COMPLETED in 21.26 seconds with 4 steps.
# Step extract COMPLETED in 7.46 seconds.
#
# Load package 1746871257.549375 is EXTRACTED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step normalize COMPLETED in 4.96 seconds.
# Normalized data for the following tables:
# - _dlt_pipeline_state: 1 row(s)
# - genome: 32169 row(s)
# - batch_stats: 4 row(s)
#
# Load package 1746871257.549375 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs
#
# Step load COMPLETED in 8.83 seconds.
# Pipeline sql_database_pipeline_with_transformers1 load step completed in 8.80 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data_20250510100057
# The duckdb destination used duckdb:////content/sql_database_pipeline_with_transformers1.duckdb location to store data
# Load package 1746871257.549375 is LOADED and contains no failed jobs
#
# Step run COMPLETED in 21.26 seconds.
# Pipeline sql_database_pipeline_with_transformers1 load step completed in 8.80 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset sql_data_20250510100057
# The duckdb destination used duckdb:////content/sql_database_pipeline_with_transformers1.duckdb location to store data
# Load package 1746871257.549375 is LOADED and contains no failed jobs

# %%
with pipeline.sql_client() as client:
  with client.execute_query("SELECT * FROM batch_stats") as table:
        res = table.df()
res
# Out:
#    batch_length   max_length       _dlt_load_id         _dlt_id
# 0         10000  13427940695  1746871257.549375  BuduPxp1kz8Y6g
# 1         10000   6250353185  1746871257.549375  M1ClY4oVSncAhg
# 2         10000  10237952243  1746871257.549375  d5r6y+im5Y1Ckg
# 3          2169   3527038434  1746871257.549375  m1oKzjYcpaNCOg

# %% [markdown]
# ## **4. Transforming data after the load**
#
# Another possibility for data transformation is transforming data after the load. dlt provides several way of doing it:
#
# * using `sql_client`,
# * via `.dataset()` and ibis integration,
# * via [dbt integration](https://dlthub.com/docs/dlt-ecosystem/transformations/dbt/).

# %% [markdown]
# ### SQL client
#
# You already saw examples of using dlt's SQL client. dlt gives you an opportunity to connect to your destination and execute any SQL query.

# %%
# NOTE: this is the duckdb sql dialect, other destinations may use different expressions
with pipeline.sql_client() as client:
    client.execute_sql(
        """ CREATE OR REPLACE TABLE genome_length AS
            SELECT
                SUM(total_length) AS total_total_length,
                AVG(total_length) AS average_total_length
            FROM
                genome
    """)
    with client.execute_query("SELECT * FROM genome_length") as table:
        genome_length = table.df()

genome_length
# Out:
#    total_total_length  average_total_length
# 0        1.519769e+12          4.724329e+07

# %% [markdown]
# ### Accessing loaded data with `pipeline.dataset()`
#
# Use `pipeline.dataset()` to inspect and work with your data in Python after loading.

# %%
dataset = pipeline.dataset()

# List tables
dataset.row_counts().df()
# Out:
#     table_name  row_count
# 0  batch_stats          4
# 1       genome      32169

# %% [markdown]
# Note that `row_counts` didn't return the new table `genome_length`,

# %%
# Access as pandas
df = dataset["genome"].df()
df
# Out:
#               upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0      RG000000001             None               NaN    None          NaN
# 1      RG000000002             None               NaN    None          NaN
# 2      RG000000003             None               NaN    None          NaN
# 3      RG000000004             None               NaN    None          NaN
# 4      RG000000005             None               NaN    None          NaN
# ...            ...              ...               ...     ...          ...
# 32164  UP001295980  GCA_963583275.1               1.0    None          NaN
# 32165  UP001296009  GCA_963583145.1               1.0    None          NaN
# 32166  UP001296230  GCA_963583065.1               1.0    None          NaN
# 32167  UP001296237  GCA_963583445.1               1.0    None          NaN
# 32168            x             None               NaN    None          NaN
#
#       assembly_name assembly_level study_ref  \
# 0              None           None      None
# 1              None           None      None
# 2              None           None      None
# 3              None           None      None
# 4              None           None      None
# ...             ...            ...       ...
# 32164          None           None      None
# 32165          None           None      None
# 32166          None           None      None
# 32167          None           None      None
# 32168     ASM2700v1           None      None
#
#                                              description  total_length  ...  \
# 0                            Potato spindle tuber viroid          4591  ...
# 1                                 Columnea latent viroid           370  ...
# 2                           Tomato apical stunt viroid-S           360  ...
# 3                             Tomato apical stunt viroid           360  ...
# 4                                 Cucumber yellows virus          7899  ...
# ...                                                  ...           ...  ...
# 32164                                               None         44107  ...
# 32165                                               None         43831  ...
# 32166                                               None         40906  ...
# 32167                                               None         42982  ...
# 32168  Pichia pastoris has been reassigned to the gen...       9216378  ...
#
#        common_name    kingdom  num_rfam_regions num_families is_reference  \
# 0             None    viroids                 0            0            1
# 1             None    viroids                 0            0            1
# 2             None    viroids                 0            0            1
# 3             None    viroids                 0            0            1
# 4             None    viruses                 0            0            1
# ...            ...        ...               ...          ...          ...
# 32164         None    viruses                 0            0            0
# 32165         None    viruses                 0            0            0
# 32166         None    viruses                 0            0            0
# 32167         None    viruses                 0            0            0
# 32168         None  eukaryota                 0            0            1
#
#       is_representative                   created                   updated  \
# 0                     0 2017-06-06 15:11:02+00:00 2020-04-23 11:46:08+00:00
# 1                     0 2017-06-06 15:11:07+00:00 2020-04-23 11:46:08+00:00
# 2                     0 2017-06-06 15:11:12+00:00 2020-04-23 11:47:10+00:00
# 3                     0 2017-06-06 15:11:17+00:00 2020-04-23 11:46:08+00:00
# 4                     0 2017-06-06 15:11:21+00:00 2020-04-23 11:46:28+00:00
# ...                 ...                       ...                       ...
# 32164                 0 2024-06-27 09:26:33+00:00 2024-09-02 20:32:58+00:00
# 32165                 0 2024-06-28 19:29:45+00:00 2024-09-02 20:32:58+00:00
# 32166                 0 2024-06-27 09:19:44+00:00 2024-09-02 20:32:58+00:00
# 32167                 0 2024-06-28 19:34:50+00:00 2024-09-02 20:32:58+00:00
# 32168                 1 2017-05-15 11:09:53+00:00 2020-04-23 11:53:16+00:00
#
#             _dlt_load_id         _dlt_id
# 0      1746871257.549375  eN2bfciLhBRmIQ
# 1      1746871257.549375  8tKbRImcxR0mpg
# 2      1746871257.549375  NQDbVdGacV3lKg
# 3      1746871257.549375  G33Oz4bVvIMjVA
# 4      1746871257.549375  hwlPZBbHzc9wew
# ...                  ...             ...
# 32164  1746871257.549375  Wi/ud/wFcUghXw
# 32165  1746871257.549375  TYFvsNwDKkJ8DQ
# 32166  1746871257.549375  8V8ATtEPFHP75g
# 32167  1746871257.549375  +w+9re10Uxpqbw
# 32168  1746871257.549375  JT9HQVA1DuAyaQ
#
# [32169 rows x 24 columns]

# %%
# Access as Arrow
arrow_table = dataset["genome_length"].arrow()
arrow_table
# Out:
# pyarrow.Table
# total_total_length: decimal128(38, 0)
# average_total_length: double
# ----
# total_total_length: [[1519769444378]]
# average_total_length: [[47243291.50355933]]

# %% [markdown]
# You can also filter, limit, and select columns:

# %%
df = dataset["genome"].select("kingdom", "ncbi_id").limit(10).df()
df
# Out:
#      kingdom  ncbi_id
# 0    viroids    12892
# 1    viroids    12901
# 2    viroids    53194
# 3    viroids    12885
# 4    viruses    32618
# 5    viruses   507757
# 6  eukaryota     5791
# 7    viruses   196399
# 8    viruses    31504
# 9    viruses    11665

# %% [markdown]
# To iterate over large data:

# %%
for chunk in dataset["genome"].iter_df(chunk_size=500):
    print(chunk.head())
# Out:
#           upid assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  RG000000001         None               NaN    None          NaN
# 1  RG000000002         None               NaN    None          NaN
# 2  RG000000003         None               NaN    None          NaN
# 3  RG000000004         None               NaN    None          NaN
# 4  RG000000005         None               NaN    None          NaN
#
#   assembly_name assembly_level study_ref                   description  \
# 0          None           None      None   Potato spindle tuber viroid
# 1          None           None      None        Columnea latent viroid
# 2          None           None      None  Tomato apical stunt viroid-S
# 3          None           None      None    Tomato apical stunt viroid
# 4          None           None      None        Cucumber yellows virus
#
#    total_length  ...  common_name  kingdom  num_rfam_regions num_families  \
# 0          4591  ...         None  viroids                 0            0
# 1           370  ...         None  viroids                 0            0
# 2           360  ...         None  viroids                 0            0
# 3           360  ...         None  viroids                 0            0
# 4          7899  ...         None  viruses                 0            0
#
#   is_reference is_representative                   created  \
# 0            1                 0 2017-06-06 15:11:02+00:00
# 1            1                 0 2017-06-06 15:11:07+00:00
# 2            1                 0 2017-06-06 15:11:12+00:00
# 3            1                 0 2017-06-06 15:11:17+00:00
# 4            1                 0 2017-06-06 15:11:21+00:00
#
#                     updated       _dlt_load_id         _dlt_id
# 0 2020-04-23 11:46:08+00:00  1746871257.549375  eN2bfciLhBRmIQ
# 1 2020-04-23 11:46:08+00:00  1746871257.549375  8tKbRImcxR0mpg
# 2 2020-04-23 11:47:10+00:00  1746871257.549375  NQDbVdGacV3lKg
# 3 2020-04-23 11:46:08+00:00  1746871257.549375  G33Oz4bVvIMjVA
# 4 2020-04-23 11:46:28+00:00  1746871257.549375  hwlPZBbHzc9wew
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  UP000003922  GCA_000167195.1               1.0    None          NaN
# 1  UP000003929                                0.0                  0.0
# 2  UP000003934  GCA_000287275.1               1.0    None          NaN
# 3  UP000003936  GCA_000287335.1               1.0                  0.0
# 4  UP000003937  GCA_000287355.1               1.0                  0.0
#
#   assembly_name   assembly_level    study_ref  \
# 0    ASM16719v1         scaffold   PRJNA10651
# 1
# 2    ASM28727v1  complete-genome  PRJNA165187
# 3    ASM28733v1                   PRJNA165193
# 4    ASM28735v1                   PRJNA165199
#
#                                          description  total_length  ...  \
# 0  ASM16719v1 assembly for Crocosphaera watsonii ...       6238156  ...
# 1        Aeropyrum coil-shaped virus complete genome         24893  ...
# 2                                               None        166163  ...
# 3  ASM28733v1 assembly for secondary endosymbiont...       1441139  ...
# 4  ASM28735v1 assembly for secondary endosymbiont...       1121596  ...
#
#    common_name   kingdom  num_rfam_regions num_families is_reference  \
# 0         None  bacteria               113           23            0
# 1                viruses                 0            0            0
# 2         None  bacteria                 0            0            0
# 3               bacteria                55           21            0
# 4               bacteria                49           17            0
#
#   is_representative                   created                   updated  \
# 0                 1 2017-04-05 18:29:46+00:00 2024-09-10 04:38:33+00:00
# 1                 1 2018-03-12 16:53:58+00:00 2018-06-16 11:40:58+00:00
# 2                 1 2024-06-27 09:23:35+00:00 2024-09-02 20:20:48+00:00
# 3                 1 2018-03-12 16:40:22+00:00 2024-09-10 04:46:32+00:00
# 4                 1 2018-03-12 16:40:21+00:00 2019-01-10 14:58:34+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  UFBBKISDzdTeng
# 1  1746871257.549375  4gC5JbiUAJ10Vw
# 2  1746871257.549375  g8dsXfpCuETgXA
# 3  1746871257.549375  AsP/PGT9N1/j3Q
# 4  1746871257.549375  iH+3P4YK8hhPDQ
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version       wgs_acc  wgs_version  \
# 0  UP000013827  GCA_000372725.1               1.0  AHAL01000000          1.0
# 1  UP000013858  GCA_000393995.1               1.0          None          NaN
# 2  UP000013866  GCA_000393935.1               1.0  AJAN01000000          1.0
# 3  UP000013893  GCA_000392435.1               1.0                        0.0
# 4  UP000013909  GCA_000390185.1               1.0  AQHR01000000          1.0
#
#                                        assembly_name assembly_level  \
# 0  Emiliana huxleyi CCMP1516 main genome assembly...
# 1                               Ente_haem_BAA-382_V1       scaffold
# 2                            Ente_vill_ATCC700913_V1
# 3                                         ASM39243v1
# 4                                              Lulo1
#
#      study_ref                                        description  \
# 0   PRJNA77753  Emiliana huxleyi CCMP1516 main genome assembly...
# 1   PRJNA88853  Ente_haem_BAA-382_V1 assembly for Enterococcus...
# 2   PRJNA88845  Ente_vill_ATCC700913_V1 assembly for Enterococ...
# 3  PRJNA201542  ASM39243v1 assembly for Candidatus Saccharimon...
# 4  PRJNA188314          Lulo1 assembly for Lunatimonas lonarensis
#
#    total_length  ...  common_name    kingdom  num_rfam_regions num_families  \
# 0     167675649  ...               eukaryota                 0            0
# 1       3580916  ...         None   bacteria                 0            0
# 2       3080759  ...                bacteria                 0            0
# 3       1013781  ...                bacteria                57           16
# 4       5392044  ...                bacteria                66           25
#
#   is_reference is_representative                   created  \
# 0            0                 1 2018-03-12 16:42:57+00:00
# 1            0                 1 2017-04-04 18:30:11+00:00
# 2            0                 1 2018-03-12 16:41:34+00:00
# 3            0                 1 2018-03-12 16:41:43+00:00
# 4            0                 1 2018-03-12 17:05:50+00:00
#
#                     updated       _dlt_load_id         _dlt_id
# 0 2024-09-10 04:55:50+00:00  1746871257.549375  qaqZrXPX3Kt9eQ
# 1 2024-09-10 04:56:07+00:00  1746871257.549375  +5OmALx+1DfCBA
# 2 2024-09-10 04:56:07+00:00  1746871257.549375  T2Mynnor+9ws9Q
# 3 2024-09-10 04:47:10+00:00  1746871257.549375  sI+aJ/L1Mjo3mQ
# 4 2024-09-10 04:46:42+00:00  1746871257.549375  tBHGHnnoThPGLA
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  UP000033024  GCA_001504635.1               1.0    None          NaN
# 1  UP000033025                                0.0                  0.0
# 2  UP000033026  GCA_001506035.1               1.0    None          NaN
# 3  UP000033035  GCA_000969825.1               1.0  AQHW01          NaN
# 4  UP000033046  GCA_000972765.1               1.0                  0.0
#
#        assembly_name   assembly_level    study_ref  \
# 0     9g like phages  complete-genome  PRJNA485481
# 1
# 2    ViralProj308015  complete-genome  PRJNA270680
# 3  Para_gord_MS-1_V1         scaffold  PRJNA170354
# 4         ASM97276v1                   PRJNA279927
#
#                                          description  total_length  ...  \
# 0                                               None         59802  ...
# 1                         Enterobacteria phage JenK1         60747  ...
# 2                                               None         38625  ...
# 3                                               None       6793348  ...
# 4  ASM97276v1 assembly for Verrucomicrobia bacter...       4001000  ...
#
#    common_name   kingdom  num_rfam_regions num_families is_reference  \
# 0         None   viruses                 0            0            1
# 1                viruses                 0            0            0
# 2         None   viruses                 0            0            0
# 3         None  bacteria                 0            0            0
# 4               bacteria                58           17            0
#
#   is_representative                   created                   updated  \
# 0                 1 2024-06-28 19:31:27+00:00 2024-09-02 20:20:59+00:00
# 1                 1 2018-03-12 16:45:28+00:00 2018-06-16 11:40:43+00:00
# 2                 1 2024-06-28 19:35:27+00:00 2024-09-02 20:20:59+00:00
# 3                 1 2024-06-28 04:52:08+00:00 2024-09-02 20:20:59+00:00
# 4                 1 2018-03-12 16:41:34+00:00 2024-09-10 04:56:14+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  SfSmYbJEP3UvRg
# 1  1746871257.549375  FhPwd+Je8/hQWQ
# 2  1746871257.549375  8wHvc+E3gt5P6Q
# 3  1746871257.549375  qIibpDZgtZwgCw
# 4  1746871257.549375  gQkalnOSO7nDEQ
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version       wgs_acc  wgs_version  \
# 0  UP000070373  GCA_001548935.1               1.0  LHXN01000000          1.0
# 1  UP000070387  GCA_001578875.1               1.0  LQRH01000000          1.0
# 2  UP000070395  GCA_001567485.1               1.0  JZRA01000000          1.0
# 3  UP000070399  GCA_001549395.1               1.0  LHYO01000000          1.0
# 4  UP000070400  GCA_001549175.1               1.0  LHXX01000000          1.0
#
#     assembly_name assembly_level    study_ref  \
# 0  SCGC-AAA259E17                 PRJNA291812
# 1     ASM157887v1                 PRJNA304333
# 2     ASM156748v1                 PRJNA274364
# 3  SCGC-AAA833F18                 PRJNA291812
# 4  SCGC-AAA261D19                 PRJNA291812
#
#                                          description  total_length  ...  \
# 0  SCGC-AAA259E17 assembly for candidate divison ...        883132  ...
# 1    ASM157887v1 assembly for Streptococcus sp. DD13       1716726  ...
# 2  ASM156748v1 assembly for Chloroflexi bacterium...       4220390  ...
# 3  SCGC-AAA833F18 assembly for candidate divison ...        269915  ...
# 4  SCGC-AAA261D19 assembly for candidate divison ...        673667  ...
#
#    common_name   kingdom  num_rfam_regions num_families is_reference  \
# 0                archaea                12            9            0
# 1               bacteria                63           32            0
# 2               bacteria                 0            0            0
# 3                archaea                 3            4            0
# 4                archaea                16           10            0
#
#   is_representative                   created                   updated  \
# 0                 1 2018-03-12 16:45:19+00:00 2024-09-10 04:48:06+00:00
# 1                 1 2018-03-12 16:45:46+00:00 2019-01-10 14:59:21+00:00
# 2                 1 2018-03-12 16:55:58+00:00 2024-09-10 04:56:13+00:00
# 3                 1 2018-03-12 16:55:58+00:00 2018-06-18 13:54:59+00:00
# 4                 1 2018-03-12 16:51:05+00:00 2024-09-10 04:48:07+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  CmbQ5QiaC2JsnA
# 1  1746871257.549375  s4rlMMWePC6htA
# 2  1746871257.549375  ATYw1RxmSYd9WA
# 3  1746871257.549375  c2uv9VaZg3g4rw
# 4  1746871257.549375  fNGEi8EtpKsZWw
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version       wgs_acc  wgs_version  \
# 0  UP000176185  GCA_001775485.1               1.0  MEWX01000000          1.0
# 1  UP000176186  GCA_001779455.1               1.0  MFKE01000000          1.0
# 2  UP000176187  GCA_001787035.1               1.0  MFUY01000000          1.0
# 3  UP000176192  GCA_001786225.1               1.0  MFVV01000000          1.0
# 4  UP000176194  GCA_001767945.1               1.0  MEMN01000000          1.0
#
#   assembly_name assembly_level    study_ref  \
# 0   ASM177548v1                 PRJNA288027
# 1   ASM177945v1                 PRJNA288027
# 2   ASM178703v1                 PRJNA288027
# 3   ASM178622v1                 PRJNA288027
# 4   ASM176794v1                 PRJNA288027
#
#                                          description  total_length  ...  \
# 0  ASM177548v1 assembly for Candidatus Adlerbacte...        608701  ...
# 1  ASM177945v1 assembly for Candidatus Gottesmanb...        927171  ...
# 2  ASM178703v1 assembly for Candidatus Nomurabact...        665914  ...
# 3  ASM178622v1 assembly for Candidatus Nomurabact...        525811  ...
# 4  ASM176794v1 assembly for Alphaproteobacteria b...       4463364  ...
#
#    common_name   kingdom  num_rfam_regions num_families is_reference  \
# 0               bacteria                 0            0            0
# 1               bacteria                 0            0            0
# 2               bacteria                 0            0            0
# 3               bacteria                 0            0            0
# 4               bacteria                 0            0            0
#
#   is_representative                   created                   updated  \
# 0                 1 2018-03-12 16:47:51+00:00 2024-09-10 04:56:16+00:00
# 1                 1 2018-03-12 16:47:52+00:00 2024-09-10 04:56:16+00:00
# 2                 1 2018-03-12 16:51:40+00:00 2024-09-10 04:56:16+00:00
# 3                 1 2018-03-12 17:03:08+00:00 2024-09-10 04:56:16+00:00
# 4                 1 2018-03-12 17:03:08+00:00 2024-09-10 04:56:15+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  JnnqJNWBId3Ndw
# 1  1746871257.549375  ksnEKUbbesap3A
# 2  1746871257.549375  HBEiD1xM1DTn7w
# 3  1746871257.549375  Aqb07oXREpm1CQ
# 4  1746871257.549375  V0pJ0ZpetMjJ+Q
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version       wgs_acc  wgs_version  \
# 0  UP000186474  GCA_001890965.1                 1  MLAY01000000          1.0
# 1  UP000186476  GCA_001914985.1                 1  MNDP01000000          1.0
# 2  UP000186483  GCA_001899775.1                 1  MKWN01000000          1.0
# 3  UP000186491  GCA_001898645.1                 1  MKUQ01000000          1.0
# 4  UP000186511  GCA_001804755.1                 1  MHBD01000000          1.0
#
#   assembly_name assembly_level    study_ref  \
# 0   ASM189096v1                 PRJNA344428
# 1   ASM191498v1                 PRJNA297196
# 2   ASM189977v1                 PRJNA279279
# 3   ASM189864v1                 PRJNA279279
# 4   ASM180475v1                 PRJNA288027
#
#                                          description  total_length  ...  \
# 0    ASM189096v1 assembly for marine bacterium AO1-C      11346547  ...
# 1  ASM191498v1 assembly for Gemmatimonadetes bact...       3773553  ...
# 2    ASM189977v1 assembly for Thiobacillus sp. 65-29       2896222  ...
# 3  ASM189864v1 assembly for Burkholderiales bacte...       4721507  ...
# 4  ASM180475v1 assembly for Legionellales bacteri...       2368910  ...
#
#    common_name   kingdom  num_rfam_regions num_families is_reference  \
# 0               bacteria               150           18            0
# 1               bacteria                 0            0            0
# 2               bacteria                 0            0            0
# 3               bacteria                 0            0            0
# 4               bacteria                 0            0            0
#
#   is_representative                   created                   updated  \
# 0                 1 2018-03-12 16:53:28+00:00 2024-09-10 04:56:18+00:00
# 1                 1 2018-03-12 16:53:28+00:00 2024-09-10 04:56:17+00:00
# 2                 1 2018-03-12 16:40:21+00:00 2024-09-10 04:56:18+00:00
# 3                 1 2018-03-12 16:51:19+00:00 2024-09-10 04:56:18+00:00
# 4                 1 2018-03-12 17:01:57+00:00 2024-09-10 04:56:16+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  8CMEjtFHDqTu6A
# 1  1746871257.549375  gwpmjZZC1OyMuA
# 2  1746871257.549375  UP9IPuNvNj33tQ
# 3  1746871257.549375  eiGYN51T1BhiGA
# 4  1746871257.549375  Z+sr4isHBPARgg
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  UP000201716  GCA_001958715.1                 1                  0.0
# 1  UP000201717  GCA_000911895.1                 1                  0.0
# 2  UP000201718  GCA_001958735.1                 1                  0.0
# 3  UP000201719  GCA_001661715.1                 1                  0.0
# 4  UP000201720  GCA_001967695.1                 1                  0.0
#
#              assembly_name assembly_level study_ref  \
# 0  ViralMultiSegProj361855
# 1          ViralProj215128
# 2          ViralProj361859
# 3          ViralProj325255
# 4          ViralProj361685
#
#                                          description  total_length  ...  \
# 0                                             Genome          4626  ...
# 1  Hemidesmus yellow mosaic virus clone H1 segmen...          2825  ...
# 2  Sanxia tombus-like virus 5 strain SXSSP12445 h...          2585  ...
# 3  Golden shiner totivirus isolate GSTV/US/MN/201...          7788  ...
# 4  Wenzhou sobemo-like virus 1 strain WZFSL61418 ...          4225  ...
#
#    common_name  kingdom  num_rfam_regions num_families is_reference  \
# 0               viruses                 0            0            0
# 1               viruses                 0            0            0
# 2               viruses                 0            0            0
# 3               viruses                 0            0            0
# 4               viruses                 0            0            0
#
#   is_representative                   created                   updated  \
# 0                 1 2018-03-12 16:41:41+00:00 2018-06-18 13:54:51+00:00
# 1                 1 2018-03-12 16:54:58+00:00 2018-06-18 13:54:59+00:00
# 2                 1 2018-03-12 16:54:55+00:00 2018-06-18 13:54:59+00:00
# 3                 1 2018-03-12 16:54:54+00:00 2018-06-18 13:54:59+00:00
# 4                 1 2018-03-12 17:03:22+00:00 2018-06-18 13:55:00+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  SQ7i9zO7sakD2Q
# 1  1746871257.549375  I+KQs65V2gkPzg
# 2  1746871257.549375  /XJ31N3lQ0/bmA
# 3  1746871257.549375  YrKH8msAYRmdZg
# 4  1746871257.549375  8NDbRQnger1rmw
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  UP000204653  GCA_000866525.1               1.0                  0.0
# 1  UP000204654  GCA_001925995.1               1.0                  0.0
# 2  UP000204655  GCA_001967075.1               1.0                  0.0
# 3  UP000204656  GCA_000919135.1               1.0                  0.0
# 4  UP000204657  GCA_001470475.1               1.0                  0.0
#
#      assembly_name assembly_level study_ref  \
# 0   ViralProj15515
# 1  ViralProj359253
# 2  ViralProj362151
# 3  ViralProj244473
# 4  ViralProj306348
#
#                                          description  total_length  ...  \
# 0  Ageratum yellow vein China virus-associated DN...          1323  ...
# 1  Lake Sinai virus strain WHCC111282 hypothetica...          5991  ...
# 2  Hubei picorna-like virus 29 strain arthropodmi...         10308  ...
# 3  Sugarcane white streak virus isolate SSNV-B [S...          2830  ...
# 4                       Edwardsiella phage PEi20 DNA        177643  ...
#
#    common_name  kingdom  num_rfam_regions num_families is_reference  \
# 0               viruses                 0            0            0
# 1               viruses                 0            0            1
# 2               viruses                 0            0            0
# 3               viruses                 0            0            0
# 4               viruses                 6            1            0
#
#   is_representative                   created                   updated  \
# 0                 0 2018-03-12 16:50:44+00:00 2018-06-18 13:54:56+00:00
# 1                 1 2018-03-12 17:04:12+00:00 2018-06-18 13:55:01+00:00
# 2                 1 2018-03-12 17:03:56+00:00 2018-06-18 13:55:01+00:00
# 3                 1 2018-03-12 16:50:43+00:00 2018-06-18 13:54:56+00:00
# 4                 1 2018-03-12 16:54:16+00:00 2018-06-18 13:54:58+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  bJ4DBDpdpBCqaQ
# 1  1746871257.549375  Oes9DrHs+n6AbQ
# 2  1746871257.549375  Yc3STBaZD1euLg
# 3  1746871257.549375  z19Z79INw5iO+w
# 4  1746871257.549375  Qd/342cfLGFdKQ
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  UP000243776  GCA_002825145.1               1.0    None          NaN
# 1  UP000243777  GCA_000840525.1               1.0    None          NaN
# 2  UP000243778  GCA_900106975.1               1.0  FNNU01          NaN
# 3  UP000243784  GCA_001854225.1               1.0    None          NaN
# 4  UP000243793  GCA_002157875.1               1.0    None          NaN
#
#                              assembly_name   assembly_level    study_ref  \
# 0                              ASM282514v1  complete-genome  PRJNA485481
# 1                   ViralMultiSegProj14262  complete-genome  PRJNA485481
# 2  IMG-taxon 2671180037 annotated assembly         scaffold   PRJEB16580
# 3                              ASM185422v1  complete-genome  PRJNA317698
# 4                              ASM215787v1  complete-genome  PRJNA387127
#
#   description  total_length  ...  common_name   kingdom  num_rfam_regions  \
# 0        None          2686  ...         None   viruses                 0
# 1        None          5192  ...         None   viruses                 0
# 2        None       4690373  ...         None  bacteria                 0
# 3        None       1424506  ...         None  bacteria                 0
# 4        None       2902896  ...         None  bacteria                 0
#
#   num_families is_reference is_representative                   created  \
# 0            0            0                 0 2024-06-27 09:19:37+00:00
# 1            0            0                 0 2024-06-27 09:25:58+00:00
# 2            0            0                 1 2024-06-28 19:29:20+00:00
# 3            0            0                 1 2024-06-28 19:37:02+00:00
# 4            0            0                 1 2024-06-27 09:21:26+00:00
#
#                     updated       _dlt_load_id         _dlt_id
# 0 2024-09-02 20:23:04+00:00  1746871257.549375  aHk3UrntdgJMig
# 1 2024-09-02 20:23:04+00:00  1746871257.549375  dOEw1sjt6X4Xzg
# 2 2024-09-02 20:23:04+00:00  1746871257.549375  uN42THgn3BNzLA
# 3 2024-09-02 20:23:04+00:00  1746871257.549375  pGDfikr7Z+i9+Q
# 4 2024-09-02 20:23:04+00:00  1746871257.549375  kl0Gr8jqiuCSmg
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  UP000287796  GCA_003989735.1                 1  RZGQ01          NaN
# 1  UP000287823  GCA_003986975.1                 1  PIPO01          NaN
# 2  UP000287829  GCA_004015685.1                 1    None          NaN
# 3  UP000287831  GCA_003673425.1                 1    None          NaN
# 4  UP000287850  GCA_004015665.1                 1    None          NaN
#
#   assembly_name   assembly_level    study_ref description  total_length  ...  \
# 0   ASM398973v1           contig  PRJNA510538        None       3407521  ...
# 1   ASM398697v1           contig  PRJNA419949        None       3099062  ...
# 2   ASM401568v1  complete-genome         None        None         39547  ...
# 3   ASM367342v1  complete-genome         None        None          2516  ...
# 4   ASM401566v1  complete-genome         None        None         37901  ...
#
#    common_name   kingdom  num_rfam_regions num_families is_reference  \
# 0         None  bacteria                 0            0            0
# 1         None  bacteria                 0            0            0
# 2         None   viruses                 0            0            0
# 3         None   viruses                 0            0            0
# 4         None   viruses                 0            0            0
#
#   is_representative                   created                   updated  \
# 0                 1 2024-06-27 09:23:00+00:00 2024-09-02 20:24:30+00:00
# 1                 1 2024-06-28 19:28:59+00:00 2024-09-02 20:24:30+00:00
# 2                 1 2024-06-28 19:36:33+00:00 2024-09-02 20:24:30+00:00
# 3                 1 2024-06-28 19:32:52+00:00 2024-09-02 20:24:31+00:00
# 4                 1 2024-06-27 09:20:16+00:00 2024-09-02 20:24:31+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  2VYxytE68hV2lg
# 1  1746871257.549375  GSP7telqnN3sGw
# 2  1746871257.549375  LYpuY3aJ4JrWPw
# 3  1746871257.549375  sFh76xy21aF6LQ
# 4  1746871257.549375  oN5N7hu7Jre5bA
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  UP000318384  GCA_007748175.1                 1    None          NaN
# 1  UP000318386  GCA_006530455.1                 1    None          NaN
# 2  UP000318405  GCA_007558815.1                 1  VLTJ01          NaN
# 3  UP000318413  GCA_006438955.1                 1  RCZK01          NaN
# 4  UP000318416  GCA_007828955.1                 1  VIVR01          NaN
#
#   assembly_name   assembly_level    study_ref description  total_length  ...  \
# 0   ASM774817v1       chromosome  PRJNA485700        None       7218541  ...
# 1   ASM653045v1  complete-genome         None        None         76991  ...
# 2   ASM755881v1           contig  PRJNA555389        None       6001989  ...
# 3   ASM643895v1           contig  PRJNA496474        None       3089412  ...
# 4   ASM782895v1           contig  PRJNA538214        None       7871666  ...
#
#    common_name   kingdom  num_rfam_regions num_families is_reference  \
# 0         None  bacteria                 0            0            0
# 1         None   viruses                 0            0            0
# 2         None  bacteria                 0            0            0
# 3         None  bacteria                 0            0            0
# 4         None  bacteria                 0            0            0
#
#   is_representative                   created                   updated  \
# 0                 1 2024-06-27 09:20:13+00:00 2024-09-02 20:26:00+00:00
# 1                 1 2024-06-27 09:19:51+00:00 2024-09-02 20:26:00+00:00
# 2                 1 2024-06-27 09:24:30+00:00 2024-09-02 20:26:00+00:00
# 3                 1 2024-06-27 09:26:46+00:00 2024-09-02 20:26:00+00:00
# 4                 1 2024-06-27 09:26:47+00:00 2024-09-02 20:26:01+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  h8i2OTtlgCqbJQ
# 1  1746871257.549375  tuzyp8pSxyK8Zg
# 2  1746871257.549375  3ymBiI61WfU0uA
# 3  1746871257.549375  57dKp/vcph0MXA
# 4  1746871257.549375  zAUTt+3VdVi+Pg
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  UP000504613  GCF_002102435.1                 1  MLBE01          NaN
# 1  UP000504614  GCF_003640425.2                 2  RBWF02          NaN
# 2  UP000504615  GCF_000187915.1                 1  ADIH01          NaN
# 3  UP000504616  GCF_000789215.1                 1  JFBF01          NaN
# 4  UP000504617  GCF_001077635.1                 1  LFLD01          NaN
#
#              assembly_name assembly_level    study_ref description  \
# 0              Ovir.te_1.0       scaffold  PRJNA317745        None
# 1              ASM364042v2       scaffold  PRJNA494147        None
# 2             Pbar_UMD_V03       scaffold   PRJNA45797        None
# 3               ASM78921v2       scaffold  PRJNA208413        None
# 4  Thamnophis_sirtalis-6.0       scaffold  PRJNA189551        None
#
#    total_length  ...         common_name    kingdom  num_rfam_regions  \
# 0    2380505687  ...                None  eukaryota                 0
# 1     401914826  ...    Greater wax moth  eukaryota                 0
# 2     235645958  ...   red harvester ant  eukaryota                 0
# 3     414984608  ...  Oriental fruit fly  eukaryota                 0
# 4    1424897867  ...                None  eukaryota                 0
#
#   num_families is_reference is_representative                   created  \
# 0            0            0                 1 2024-06-27 09:25:32+00:00
# 1            0            0                 1 2024-06-28 19:36:48+00:00
# 2            0            0                 1 2024-06-28 19:34:57+00:00
# 3            0            0                 1 2024-06-27 09:23:21+00:00
# 4            0            0                 1 2024-06-27 09:24:38+00:00
#
#                     updated       _dlt_load_id         _dlt_id
# 0 2024-09-02 20:27:29+00:00  1746871257.549375  UCjaJkmBWQqROA
# 1 2024-09-02 20:27:29+00:00  1746871257.549375  /H7qt8xVv9wLgA
# 2 2024-09-02 20:27:29+00:00  1746871257.549375  69ayn9/lO7m92A
# 3 2024-09-02 20:27:29+00:00  1746871257.549375  SjYlt0NDnbbY4w
# 4 2024-09-02 20:27:30+00:00  1746871257.549375  Wcs7kqswPWV1fA
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version   wgs_acc  wgs_version  \
# 0  UP000652041  GCA_014385435.1                 1  JACSUD01          NaN
# 1  UP000652231  GCA_014640155.1                 1    BMGK01          NaN
# 2  UP000652354  GCA_016862815.1                 1    BONR01          NaN
# 3  UP000652477  GCA_014287475.1                 1  JACOPF01          NaN
# 4  UP000652501  GCA_016836245.1                 1      None          NaN
#
#   assembly_name   assembly_level    study_ref description  total_length  ...  \
# 0  ASM1438543v1           contig  PRJNA658455        None       2486202  ...
# 1  ASM1464015v1           contig   PRJDB10509        None       2966703  ...
# 2  ASM1686281v1           contig    PRJDB9996        None       2471820  ...
# 3  ASM1428747v1           contig  PRJNA656402        None       3598112  ...
# 4  ASM1683624v1  complete-genome         None        None        120547  ...
#
#    common_name   kingdom  num_rfam_regions num_families is_reference  \
# 0         None  bacteria                 0            0            0
# 1         None  bacteria                 0            0            0
# 2         None  bacteria                 0            0            0
# 3         None  bacteria                 0            0            0
# 4         None   viruses                 0            0            0
#
#   is_representative                   created                   updated  \
# 0                 1 2024-06-28 19:30:08+00:00 2024-09-02 20:28:50+00:00
# 1                 1 2024-06-27 09:21:33+00:00 2024-09-02 20:28:50+00:00
# 2                 1 2024-06-27 09:21:15+00:00 2024-09-02 20:28:50+00:00
# 3                 1 2024-06-27 09:24:53+00:00 2024-09-02 20:28:50+00:00
# 4                 1 2024-06-27 09:25:51+00:00 2024-09-02 20:28:50+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  KuT45ePQapQvyw
# 1  1746871257.549375  toDS0AepCNe4Og
# 2  1746871257.549375  86Cp8f1TuG2xlw
# 3  1746871257.549375  SpvUjPRmySoNkw
# 4  1746871257.549375  hPA3L4dk9tJjDw
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version   wgs_acc  wgs_version  \
# 0  UP000807716  GCA_016098155.1                 1  JAAAJB01          NaN
# 1  UP000807769  GCA_016647635.1                 1  JABBWG01          NaN
# 2  UP000808372  GCF_016432855.1                 1  JAEAGN01          NaN
# 3  UP000809243  GCA_016932355.1                 1  JAFGDB01          NaN
# 4  UP000809273  GCA_016929395.1                 1  JAFGIX01          NaN
#
#         assembly_name assembly_level    study_ref description  total_length  \
# 0  UCR_MambBC1055_1.0       scaffold  PRJNA463334        None      37923144
# 1             Suisub1         contig  PRJNA346342        None      57660940
# 2          SaNama_1.0     chromosome  PRJNA682269        None    2345513378
# 3        ASM1693235v1         contig  PRJNA690107        None       1068444
# 4        ASM1692939v1         contig  PRJNA690107        None       3762314
#
#    ...  common_name    kingdom  num_rfam_regions num_families is_reference  \
# 0  ...         None  eukaryota                 0            0            0
# 1  ...         None  eukaryota                 0            0            0
# 2  ...   Lake trout  eukaryota                 0            0            0
# 3  ...         None    archaea                 0            0            0
# 4  ...         None   bacteria                 0            0            0
#
#   is_representative                   created                   updated  \
# 0                 1 2024-06-28 19:28:53+00:00 2024-09-02 20:30:19+00:00
# 1                 1 2024-06-27 09:24:24+00:00 2024-09-02 20:30:19+00:00
# 2                 1 2024-06-27 09:41:31+00:00 2024-09-02 20:30:19+00:00
# 3                 1 2024-06-28 19:32:19+00:00 2024-09-02 20:30:19+00:00
# 4                 1 2024-06-27 09:22:48+00:00 2024-09-02 20:30:19+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  TkqGcisyiwPrAw
# 1  1746871257.549375  NRAItlgyw7DXOg
# 2  1746871257.549375  gyxIHbAVXM0Mpw
# 3  1746871257.549375  Cogdog8YomxwUg
# 4  1746871257.549375  Mrxu1cOCg3BPZg
#
# [5 rows x 24 columns]
#           upid     assembly_acc  assembly_version wgs_acc  wgs_version  \
# 0  UP001226325  GCA_031216175.1               1.0    None          NaN
# 1  UP001226334  GCA_031201065.1               1.0    None          NaN
# 2  UP001226339  GCA_031190845.1               1.0    None          NaN
# 3  UP001226340  GCA_031225955.1               1.0    None          NaN
# 4  UP001226356  GCA_031106045.1               1.0    None          NaN
#
#   assembly_name   assembly_level study_ref description  total_length  ...  \
# 0  ASM3121617v1  complete-genome      None        None          3202  ...
# 1  ASM3120106v1  complete-genome      None        None          3360  ...
# 2  ASM3119084v1  complete-genome      None        None          3209  ...
# 3  ASM3122595v1  complete-genome      None        None          3150  ...
# 4  ASM3110604v1  complete-genome      None        None          6497  ...
#
#    common_name  kingdom  num_rfam_regions num_families is_reference  \
# 0         None  viruses                 0            0            0
# 1         None  viruses                 0            0            0
# 2         None  viruses                 0            0            0
# 3         None  viruses                 0            0            0
# 4         None  viruses                 0            0            0
#
#   is_representative                   created                   updated  \
# 0                 0 2024-06-28 19:34:49+00:00 2024-09-02 20:31:50+00:00
# 1                 0 2024-06-27 09:26:43+00:00 2024-09-02 20:31:50+00:00
# 2                 0 2024-06-27 09:22:28+00:00 2024-09-02 20:31:50+00:00
# 3                 0 2024-06-28 19:31:18+00:00 2024-09-02 20:31:50+00:00
# 4                 0 2024-06-27 09:27:20+00:00 2024-09-02 20:31:50+00:00
#
#         _dlt_load_id         _dlt_id
# 0  1746871257.549375  CU7cdE0UddWRqQ
# 1  1746871257.549375  xIF+GzQRq2MM5Q
# 2  1746871257.549375  +srru8pSQjEvdA
# 3  1746871257.549375  b9SWuGQijOCWcA
# 4  1746871257.549375  z9M3iihL0T02Bg
#
# [5 rows x 24 columns]

# %% [markdown]
# For more advanced users, this interface supports **Ibis expressions**, joins, and subqueries.

# %% [markdown]
# ### Ibis integration
#
# Ibis is a powerful portable Python dataframe library. Learn more about what it is and how to use it in the [official documentation](https://ibis-project.org/).
#
# [dlt provides a way to use Ibis expressions natively](https://dlthub.com/docs/general-usage/dataset-access/ibis-backend) with a lot of destinations. Supported ones are:
# * Snowflake
# * DuckDB
# * MotherDuck
# * Postgres
# * Redshift
# * Clickhouse
# * MSSQL (including Synapse)
# * BigQuery

# %%
# !pip install ibis-framework[duckdb]
# Out:
# Requirement already satisfied: ibis-framework[duckdb] in /usr/local/lib/python3.11/dist-packages (9.5.0)
# Requirement already satisfied: atpublic<6,>=2.3 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (5.1)
# Requirement already satisfied: duckdb<1.2,>=0.8.1 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (1.1.3)
# Requirement already satisfied: numpy<3,>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (2.0.2)
# Requirement already satisfied: packaging<25,>=21.3 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (24.2)
# Requirement already satisfied: pandas<3,>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (2.2.2)
# Requirement already satisfied: parsy<3,>=2 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (2.1)
# Requirement already satisfied: pyarrow<18,>=10.0.1 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (17.0.0)
# Requirement already satisfied: pyarrow-hotfix<1,>=0.4 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (0.7)
# Requirement already satisfied: python-dateutil<3,>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2022.7 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (2025.2)
# Requirement already satisfied: rich<14,>=12.4.4 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (13.9.4)
# Requirement already satisfied: sqlglot<25.21,>=23.4 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (25.20.2)
# Requirement already satisfied: toolz<1,>=0.11 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (0.12.1)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from ibis-framework[duckdb]) (4.13.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.5.3->ibis-framework[duckdb]) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3,>=2.8.2->ibis-framework[duckdb]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=12.4.4->ibis-framework[duckdb]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14,>=12.4.4->ibis-framework[duckdb]) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=12.4.4->ibis-framework[duckdb]) (0.1.2)

# %%
# get the dataset from the pipeline
dataset = pipeline.dataset()
dataset_name = pipeline.dataset_name

# get the native ibis connection from the dataset
ibis_connection = dataset.ibis()

# list all tables in the dataset
# NOTE: You need to provide the dataset name to ibis, in ibis datasets are named databases
print(ibis_connection.list_tables(database=dataset_name))

# get the items table
table = ibis_connection.table("batch_stats", database=dataset_name)

# print the first 2 rows
print(table.limit(2).execute())
# Out:
# ['_dlt_loads', '_dlt_pipeline_state', '_dlt_version', 'batch_stats', 'genome', 'genome_length']
#    batch_length   max_length       _dlt_load_id         _dlt_id
# 0         10000  13427940695  1746871257.549375  BuduPxp1kz8Y6g
# 1         10000   6250353185  1746871257.549375  M1ClY4oVSncAhg

# %% [markdown]
# ✅ ▶ Proceed to the [next lesson](https://colab.research.google.com/drive/1XT1xUIQIWj0nPWOmTixThgdXzi4vudce#forceEdit=true&sandboxMode=true)!
